# %%
import pandas as pd

# 讀取 CSV 檔案
df = pd.read_csv('wave_1year.csv')

# 設定索引
index = df['Date_Time']
values = df['港外波高_HS']

# 確保 'Date_Time' 欄位為日期格式
df['Date_Time'] = pd.to_datetime(df['Date_Time'])

# 讓使用者輸入篩選的日期範圍
start = input("請輸入輸出的起始年月日時,如2023/1/1 00:00: ")
end = input("請輸入輸出的結束年月日時,如2023/1/31 23:00: ")
start_date = pd.to_datetime(start)
end_date = pd.to_datetime(end)

# 篩選指定日期範圍的數據
df_selected = df[(df['Date_Time'] >= start_date) & (df['Date_Time'] <= end_date)]
df_selected

# 將篩選後的數據儲存為新的 CSV 檔案
#df_selected.to_csv(f'wave_{start_date.strftime("%Y%m%d")}_{end_date.strftime("%Y%m%d")}.csv', index=False)
# Out:
#               Date_Time  港外波高_HS
# 743 2023-02-01 00:00:00     0.90
# 744 2023-02-01 01:00:00     0.87
# 745 2023-02-01 02:00:00     0.91
# 746 2023-02-01 03:00:00     0.82
# 747 2023-02-01 04:00:00     0.85
# ..                  ...      ...
# 799 2023-02-03 08:00:00     1.22
# 800 2023-02-03 09:00:00     1.20
# 801 2023-02-03 10:00:00     1.28
# 802 2023-02-03 11:00:00     1.31
# 803 2023-02-03 12:00:00     1.15
#
# [61 rows x 2 columns]
