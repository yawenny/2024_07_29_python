# %%
#index和columns的名字
import numpy as np
import pandas as pd

scores = np.random.randint(50,101,size=(50,5))
scores_df =pd.DataFrame(scores,
             columns=['國文','英文','數學','地理','歷史'],
             index=range(1,51))
type(scores_df.index)
scores_df.index.name='學號'
scores_df.columns.name='科目'
scores_df
# Out:
# 科目  國文   英文   數學  地理   歷史
# 學號
# 1   52   80   91  66   95
# 2   78   69   96  69   74
# 3   59   78   80  54   57
# 4   83   60   71  96   99
# 5   91   95   81  94   56
# 6   51   85   84  63   69
# 7   98   72  100  52   70
# 8   70   91   75  78   62
# 9   81   96   92  65  100
# 10  83   58   92  90   51
# 11  79   95   79  69   97
# 12  79   76   87  99   63
# 13  67   90   71  87   99
# 14  86   94   79  83   71
# 15  56   68   60  77   88
# 16  94   98   74  51   83
# 17  61   58  100  85   84
# 18  96   87   53  64   90
# 19  77   50   67  50   74
# 20  70   51   83  76   63
# 21  76   77   83  62   56
# 22  84   64   75  55   86
# 23  54   81   75  72   71
# 24  60   60   53  66   67
# 25  54   56   92  85   68
# 26  63   94   78  85   61
# 27  68   66   62  63   76
# 28  72   54   88  85   98
# 29  66   75   99  63   95
# 30  54   74   98  59   78
# 31  78   52   93  75   51
# 32  80   59   74  65   71
# 33  93   65   99  63   54
# 34  77   88   50  65   97
# 35  75   83   90  63   73
# 36  71   87   52  91   89
# 37  62   56   75  67   60
# 38  66   95   51  57   76
# 39  78   95   75  50   57
# 40  94   53   86  63   82
# 41  57   83   72  50   54
# 42  96   82   93  75   79
# 43  78   75   63  72   70
# 44  87   56   82  71   89
# 45  59   68   71  71   56
# 46  73   53   75  55   73
# 47  79   58   86  91   53
# 48  85   72   57  83   64
# 49  68   96   58  76   86
# 50  76  100   96  58   78

# %%
#將每一欄series計算統計後,再合併為dataframe
def call(s):
    min = s.min()
    max = s.max()
    median = s.median()
    return pd.Series([min,max,median],index=['最低分','最高分','中間值'])

scores_df.apply(call)
# Out:
# 科目     國文     英文     數學    地理     歷史
# 最低分  51.0   50.0   50.0  50.0   51.0
# 最高分  98.0  100.0  100.0  99.0  100.0
# 中間值  76.0   75.0   79.0  68.0   73.0

# %%
#列series,及格及不及格的數量
def call1(s):
    less60 = s[s<60]
    return less60.count()

less60_s = scores_df.apply(call1,axis=1)
scores_df['不及格的科目']=less60_s
scores_df
# Out:
# 科目  國文   英文   數學  地理   歷史  不及格的科目
# 學號
# 1   52   80   91  66   95       1
# 2   78   69   96  69   74       0
# 3   59   78   80  54   57       3
# 4   83   60   71  96   99       0
# 5   91   95   81  94   56       1
# 6   51   85   84  63   69       1
# 7   98   72  100  52   70       1
# 8   70   91   75  78   62       0
# 9   81   96   92  65  100       0
# 10  83   58   92  90   51       2
# 11  79   95   79  69   97       0
# 12  79   76   87  99   63       0
# 13  67   90   71  87   99       0
# 14  86   94   79  83   71       0
# 15  56   68   60  77   88       1
# 16  94   98   74  51   83       1
# 17  61   58  100  85   84       1
# 18  96   87   53  64   90       1
# 19  77   50   67  50   74       2
# 20  70   51   83  76   63       1
# 21  76   77   83  62   56       1
# 22  84   64   75  55   86       1
# 23  54   81   75  72   71       1
# 24  60   60   53  66   67       1
# 25  54   56   92  85   68       2
# 26  63   94   78  85   61       0
# 27  68   66   62  63   76       0
# 28  72   54   88  85   98       1
# 29  66   75   99  63   95       0
# 30  54   74   98  59   78       2
# 31  78   52   93  75   51       2
# 32  80   59   74  65   71       1
# 33  93   65   99  63   54       1
# 34  77   88   50  65   97       1
# 35  75   83   90  63   73       0
# 36  71   87   52  91   89       1
# 37  62   56   75  67   60       1
# 38  66   95   51  57   76       2
# 39  78   95   75  50   57       2
# 40  94   53   86  63   82       1
# 41  57   83   72  50   54       3
# 42  96   82   93  75   79       0
# 43  78   75   63  72   70       0
# 44  87   56   82  71   89       1
# 45  59   68   71  71   56       2
# 46  73   53   75  55   73       2
# 47  79   58   86  91   53       2
# 48  85   72   57  83   64       1
# 49  68   96   58  76   86       1
# 50  76  100   96  58   78       1
